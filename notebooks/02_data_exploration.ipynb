# %% [markdown]
# # Imports

# %%
from utils.data_exploration_utils import *

# %%
target_path= f'../datasets/clean_datasets/australia_data.parquet'
df_australia= pd.read_parquet(target_path)

# %% [markdown]
# # Australia

# %%
show_df_metrics(df_australia)

df_australia['date'] = pd.to_datetime(df_australia['date'])
# Se ordena por fecha
df_australia = df_australia.sort_values(by='date')

df_pivot = df_australia.pivot(index='date', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3285 entries, 0 to 3284
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        3285 non-null   object
#  1   admissions  3198 non-null   float64
#  2   hospital    3285 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 77.1+ KB
#
# Porcentaje de nulos por columna:
# admissions    2.648402
# date          0.000000
# hospital      0.000000
# dtype: float64
#
# Duplicados:
# 0
# C:\Users\David\AppData\Local\Temp\ipykernel_4784\1163136098.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_australia['date'] = pd.to_datetime(df_australia['date'])

# %% [markdown]
# # Betania

# %%
target_path= f'../datasets/clean_datasets/betania_data.parquet'
df_betania= pd.read_parquet(target_path)

# %%
show_df_metrics(df_betania)

df_betania['date'] = pd.to_datetime(df_betania['date'])
# Se ordena por fecha
df_betania = df_betania.sort_values(by='date')

df_pivot = df_betania.pivot(index='date', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4155 entries, 0 to 4154
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        4155 non-null   object
#  1   admissions  4155 non-null   int64
#  2   hospital    4155 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 97.5+ KB
#
# Porcentaje de nulos por columna:
# date          0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %% [markdown]
# # Botswama

# %%
target_path= f'../datasets/clean_datasets/botswana_data.parquet'
df_botswana= pd.read_parquet(target_path)

# %%
show_df_metrics(df_botswana)

df_botswana['date'] = df_botswana['date'].astype(str)

# Convierte usando el formato AAAAMMDD
df_botswana['date'] = pd.to_datetime(df_botswana['date'], format='%Y%m%d')
# Se ordena por fecha
df_botswana = df_botswana.sort_values(by='date')
df_botswana.head()
df_pivot = df_botswana.pivot(index='date', columns='hospital', values='admissions')


print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52596 entries, 0 to 52595
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        52596 non-null  int64
#  1   hospital    52596 non-null  object
#  2   admissions  52596 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ MB
#
# Porcentaje de nulos por columna:
# date          0.0
# hospital      0.0
# admissions    0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/cardiff_data.parquet'
df_cardiff= pd.read_parquet(target_path)

# %%
show_df_metrics(df_cardiff)

df_cardiff = df_cardiff.groupby(['datetime', 'hospital'])['admissions'].sum().reset_index()


df_cardiff['datetime'] = pd.to_datetime(df_cardiff['datetime']).dt.tz_localize(None)

# Se ordena por fecha
df_cardiff = df_cardiff.sort_values(by='datetime')
df_cardiff.head()
df_pivot = df_cardiff.pivot(index='datetime', columns='hospital', values='admissions')


print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86161 entries, 0 to 86160
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    86161 non-null  object
#  1   admissions  86161 non-null  int64
#  2   hospital    86161 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 2.0+ MB
#
# Porcentaje de nulos por columna:
# datetime      0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 19396

# %%
target_path= f'../datasets/clean_datasets/chile_data.parquet'
df_chile= pd.read_parquet(target_path)

# %%
show_df_metrics(df_chile)

top_hospitals = df_chile.groupby('hospital')['admissions'].sum().nlargest(10).index
df_chile = df_chile[df_chile['hospital'].isin(top_hospitals)]

df_chile['date'] = df_chile['date'].astype(str)

# Convierte usando el formato AAAAMMDD
df_chile['date'] = pd.to_datetime(df_chile['date'])
# Se ordena por fecha
df_chile = df_chile.sort_values(by='date')
df_chile.head()
df_pivot = df_chile.pivot(index='date', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2742885 entries, 0 to 2742884
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   date        datetime64[ns]
#  1   admissions  int64
#  2   hospital    object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 62.8+ MB
#
# Porcentaje de nulos por columna:
# date          0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/colombia_data.parquet'
df_colombia= pd.read_parquet(target_path)

# %%
show_df_metrics(df_colombia)

df_colombia['datetime'] = pd.to_datetime(df_colombia['datetime'])

# Se ordena por fecha
df_colombia = df_colombia.sort_values(by='datetime')

df_pivot = df_colombia.pivot(index='datetime', columns='hospital', values='admissions')


print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77024 entries, 0 to 77023
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    77024 non-null  datetime64[ns]
#  1   admissions  77024 non-null  int64
#  2   hospital    77024 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.8+ MB
#
# Porcentaje de nulos por columna:
# datetime      0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/iowa_data.parquet'
df_iowa= pd.read_parquet(target_path)

# %%
show_df_metrics(df_iowa)

df_iowa['datetime'] = pd.to_datetime(df_iowa['datetime'])

# Se ordena por fecha
df_iowa = df_iowa.sort_values(by='datetime')

df_pivot = df_iowa.pivot(index='datetime', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33120 entries, 0 to 33119
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    33120 non-null  datetime64[ns]
#  1   admissions  30887 non-null  float64
#  2   hospital    33120 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 776.4+ KB
#
# Porcentaje de nulos por columna:
# admissions    6.74215
# datetime      0.00000
# hospital      0.00000
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/iran_data.parquet'
df_iran= pd.read_parquet(target_path)

# %%
show_df_metrics(df_iran)

df_iran['datetime'] = pd.to_datetime(df_iran['datetime'])

# Se ordena por fecha
df_iran = df_iran.sort_values(by='datetime')

df_pivot = df_iran.pivot(index='datetime', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39249 entries, 0 to 39248
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    39249 non-null  datetime64[ns]
#  1   admissions  39249 non-null  int64
#  2   hospital    39249 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 920.0+ KB
#
# Porcentaje de nulos por columna:
# datetime      0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/mexico_data.parquet'
df_mexico= pd.read_parquet(target_path)

# %%
show_df_metrics(df_mexico)

top_hospitals = df_mexico.groupby('hospital')['admissions'].sum().nlargest(10).index
df_mexico = df_mexico[df_mexico['hospital'].isin(top_hospitals)]

df_mexico['datetime'] = df_mexico['datetime'].astype(str)

df_mexico['datetime'] = pd.to_datetime(df_mexico['datetime'])

df_mexico = df_mexico.groupby(['datetime', 'hospital'])['admissions'].sum().reset_index()
# Se ordena por fecha
df_mexico = df_mexico.sort_values(by='datetime')
df_mexico.head()

df_pivot = df_mexico.pivot(index='datetime', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999299 entries, 0 to 7999298
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   datetime    datetime64[ns]
#  1   admissions  int64
#  2   hospital    object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 183.1+ MB
#
# Porcentaje de nulos por columna:
# datetime      0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/netherlands_data.parquet'
df_netherlands= pd.read_parquet(target_path)

# %%
show_df_metrics(df_netherlands)

df_netherlands['date'] = df_netherlands['date'].astype(str)

# Convierte usando el formato AAAAMMDD
df_netherlands['date'] = pd.to_datetime(df_netherlands['date'], format='%Y%m%d')
# Se ordena por fecha
df_netherlands = df_netherlands.sort_values(by='date')
df_netherlands.head()
df_pivot = df_netherlands.pivot(index='date', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52596 entries, 0 to 52595
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        52596 non-null  int64
#  1   hospital    52596 non-null  object
#  2   admissions  52596 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ MB
#
# Porcentaje de nulos por columna:
# date          0.0
# hospital      0.0
# admissions    0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/pakistan_data.parquet'
df_pakistan= pd.read_parquet(target_path)

# %%
show_df_metrics(df_pakistan)

df_pakistan['date'] = df_pakistan['date'].astype(str)

# Convierte usando el formato AAAAMMDD
df_pakistan['date'] = pd.to_datetime(df_pakistan['date'], format='%Y%m%d')
# Se ordena por fecha
df_pakistan = df_pakistan.sort_values(by='date')
df_pakistan.head()
df_pivot = df_pakistan.pivot(index='date', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52596 entries, 0 to 52595
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        52596 non-null  int64
#  1   hospital    52596 non-null  object
#  2   admissions  52596 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ MB
#
# Porcentaje de nulos por columna:
# date          0.0
# hospital      0.0
# admissions    0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/spain_data.parquet'
df_spain= pd.read_parquet(target_path)

# %%
show_df_metrics(df_spain)

df_spain['date'] = df_spain['date'].astype(str)

# Convierte usando el formato AAAAMMDD
df_spain['date'] = pd.to_datetime(df_spain['date'])
# Se ordena por fecha
df_spain = df_spain.sort_values(by='date')
df_spain.head()

print_top10_graph(df_spain)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42789 entries, 0 to 42788
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        42789 non-null  object
#  1   admissions  42789 non-null  int64
#  2   hospital    42789 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1003.0+ KB
#
# Porcentaje de nulos por columna:
# date          0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/usa_data.parquet'
df_usa= pd.read_parquet(target_path)

# %%
show_df_metrics(df_usa)

df_usa['date'] = df_usa['date'].astype(str)

# Convierte usando el formato AAAAMMDD
df_usa['date'] = pd.to_datetime(df_usa['date'], format='%Y%m%d')
# Se ordena por fecha
df_usa = df_usa.sort_values(by='date')
df_usa.head()
df_pivot = df_usa.pivot(index='date', columns='hospital', values='admissions')


print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52596 entries, 0 to 52595
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        52596 non-null  int64
#  1   admissions  52596 non-null  float64
#  2   hospital    52596 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ MB
#
# Porcentaje de nulos por columna:
# date          0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0

# %%
target_path= f'../datasets/clean_datasets/wales_data.parquet'
df_wales= pd.read_parquet(target_path)

# %%
show_df_metrics(df_wales)

# Convierte usando el formato AAAAMMDD
df_wales['date'] = pd.to_datetime(df_wales['date'])
df_wales['admissions'] = pd.to_numeric(df_wales['admissions'], errors='coerce')

# Se ordena por fecha
df_wales = df_wales.sort_values(by='date')
df_wales.head()
df_pivot = df_wales.pivot(index='date', columns='hospital', values='admissions')

print_graph(df_pivot)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3437 entries, 0 to 3436
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        3437 non-null   object
#  1   admissions  3437 non-null   object
#  2   hospital    3437 non-null   object
# dtypes: object(3)
# memory usage: 80.7+ KB
#
# Porcentaje de nulos por columna:
# date          0.0
# admissions    0.0
# hospital      0.0
# dtype: float64
#
# Duplicados:
# 0
